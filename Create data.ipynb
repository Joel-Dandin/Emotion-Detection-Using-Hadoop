# %%
import string

# %%
# !wget "http://deepyeti.ucsd.edu/jianmo/amazon/categoryFiles/Arts_Crafts_and_Sewing.json.gz"
# Out:
# --2022-10-03 18:03:12--  http://deepyeti.ucsd.edu/jianmo/amazon/categoryFiles/Arts_Crafts_and_Sewing.json.gz
# Resolving deepyeti.ucsd.edu (deepyeti.ucsd.edu)... 169.228.63.50
# Connecting to deepyeti.ucsd.edu (deepyeti.ucsd.edu)|169.228.63.50|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 306424435 (292M) [application/octet-stream]
# Saving to: ‘Arts_Crafts_and_Sewing.json.gz’
#
# Arts_Crafts_and_Sew 100%[===================>] 292.23M  18.7MB/s    in 17s
#
# 2022-10-03 18:03:29 (16.9 MB/s) - ‘Arts_Crafts_and_Sewing.json.gz’ saved [306424435/306424435]

# %%
# !gzip -d Arts_Crafts_and_Sewing.json.gz

# %%
import pandas as pd

df = pd.read_json("Arts_Crafts_and_Sewing.json", lines=True)

# %%
df
# Out:
#          overall vote  verified   reviewTime      reviewerID        asin  \
# 0              5    4      True   11 6, 2013  A3U4E9PIZ8OWH1  0449819906
# 1              5  NaN      True  02 28, 2017  A3945D2TJ0PI86  0449819906
# 2              5  NaN      True  02 25, 2017  A2WZK72HLQ7SPT  0449819906
# 3              5  NaN      True  01 25, 2017  A1Q7YJ1NPE6E0W  0449819906
# 4              5  NaN      True  01 12, 2017  A2846L8Q507JC4  0449819906
# ...          ...  ...       ...          ...             ...         ...
# 2875912        3    2      True   12 5, 2016  A3DBSNSXS3HLW2  B01HJHR2PM
# 2875913        5  NaN      True   12 1, 2016  A335NB837Q8LWN  B01HJHR2PM
# 2875914        5  NaN      True  10 25, 2016   AKWXQAVB2U5ME  B01HJHR2PM
# 2875915        1    3      True  10 24, 2016  A2CWSI0186P0AY  B01HJHR2PM
# 2875916        1    3      True  09 21, 2016  A172Y8313QKCNZ  B01HJHR2PM
#
#                                   style     reviewerName  \
# 0        {'Format:': ' Kindle Edition'}   Shirley Curtis
# 1        {'Format:': ' Kindle Edition'}         M. Smith
# 2             {'Format:': ' Paperback'}  Amazon Customer
# 3        {'Format:': ' Kindle Edition'}        MargaretT
# 4        {'Format:': ' Kindle Edition'}            Dulce
# ...                                 ...              ...
# 2875912                             NaN  Amazon Customer
# 2875913                             NaN     Kendra Swain
# 2875914                             NaN    Fastfinal6565
# 2875915                             NaN            Oscar
# 2875916                             NaN        spartacus
#
#                                                 reviewText  \
# 0        I've read this book already and I've got plans...
# 1                               Nicely written directions.
# 2                                                  love it
# 3        Good additional knitting reference to have ava...
# 4        A gazillion pattern stitches, lucidly explaine...
# ...                                                    ...
# 2875912  The pens took weeks to arrive and ran out of i...
# 2875913  Used these on our wedding canvas guest book, t...
# 2875914                                     LOVE LOVE LOVE
# 2875915  color won't stop running once you activate the...
# 2875916  I received these earlier than expected. Have r...
#
#                                                    summary  unixReviewTime  \
# 0                                        A  WONDERFUL BOOK      1383696000
# 1                                                     Nice      1488240000
# 2                                               Five Stars      1487980800
# 3                         Good Reference in Kindle Edition      1485302400
# 4                                Extremely clear, thorough      1484179200
# ...                                                    ...             ...
# 2875912  ... took weeks to arrive and ran out of ink pr...      1480896000
# 2875913                                    Great product!!      1480550400
# 2875914                                         Five Stars      1477353600
# 2875915                                           One Star      1477267200
# 2875916                                          One color      1474416000
#
#         image
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ...       ...
# 2875912   NaN
# 2875913   NaN
# 2875914   NaN
# 2875915   NaN
# 2875916   NaN
#
# [2875917 rows x 12 columns]

# %%
df = df.drop(['vote','verified','reviewTime','reviewerID','style','reviewerName','unixReviewTime','image'], inplace=True, axis=1)

# %%
df
# Out:
#          overall        asin  \
# 0              5  0449819906
# 1              5  0449819906
# 2              5  0449819906
# 3              5  0449819906
# 4              5  0449819906
# ...          ...         ...
# 2875912        3  B01HJHR2PM
# 2875913        5  B01HJHR2PM
# 2875914        5  B01HJHR2PM
# 2875915        1  B01HJHR2PM
# 2875916        1  B01HJHR2PM
#
#                                                 reviewText  \
# 0        I've read this book already and I've got plans...
# 1                               Nicely written directions.
# 2                                                  love it
# 3        Good additional knitting reference to have ava...
# 4        A gazillion pattern stitches, lucidly explaine...
# ...                                                    ...
# 2875912  The pens took weeks to arrive and ran out of i...
# 2875913  Used these on our wedding canvas guest book, t...
# 2875914                                     LOVE LOVE LOVE
# 2875915  color won't stop running once you activate the...
# 2875916  I received these earlier than expected. Have r...
#
#                                                    summary
# 0                                        A  WONDERFUL BOOK
# 1                                                     Nice
# 2                                               Five Stars
# 3                         Good Reference in Kindle Edition
# 4                                Extremely clear, thorough
# ...                                                    ...
# 2875912  ... took weeks to arrive and ran out of ink pr...
# 2875913                                    Great product!!
# 2875914                                         Five Stars
# 2875915                                           One Star
# 2875916                                          One color
#
# [2875917 rows x 4 columns]

# %%
null_data = df[df.isnull().any(axis=1)]

# %%
null_data
# Out:
#          overall        asin  \
# 5468           5  B00004THXH
# 5585           5  B00004THXH
# 7599           5  B00004Z2U8
# 8032           4  B00004Z2UD
# 10904          5  B00006IAHD
# ...          ...         ...
# 2874029        5  B01HDZY2WQ
# 2874157        5  B01HEDV9SC
# 2875590        5  B01HIIFJ8Y
# 2875603        1  B01HIIV3Y8
# 2875807        5  B01HJ6SMSY
#
#                                                 reviewText     summary
# 5468                                                   NaN  Five Stars
# 5585     Just what I was looking for... a little hard t...         NaN
# 7599                                                   NaN  Five Stars
# 8032                                                   NaN  Four Stars
# 10904                                                  NaN         NaN
# ...                                                    ...         ...
# 2874029                                     Great stuff!!!         NaN
# 2874157  I used these to cover my bf's house while he w...         NaN
# 2875590                                                NaN  Five Stars
# 2875603                                                NaN  Never Came
# 2875807                                                NaN  Five Stars
#
# [3399 rows x 4 columns]

# %%
df = df.dropna()

# %%
df
# Out:
#          overall        asin  \
# 0              5  0449819906
# 1              5  0449819906
# 2              5  0449819906
# 3              5  0449819906
# 4              5  0449819906
# ...          ...         ...
# 2875912        3  B01HJHR2PM
# 2875913        5  B01HJHR2PM
# 2875914        5  B01HJHR2PM
# 2875915        1  B01HJHR2PM
# 2875916        1  B01HJHR2PM
#
#                                                 reviewText  \
# 0        I've read this book already and I've got plans...
# 1                               Nicely written directions.
# 2                                                  love it
# 3        Good additional knitting reference to have ava...
# 4        A gazillion pattern stitches, lucidly explaine...
# ...                                                    ...
# 2875912  The pens took weeks to arrive and ran out of i...
# 2875913  Used these on our wedding canvas guest book, t...
# 2875914                                     LOVE LOVE LOVE
# 2875915  color won't stop running once you activate the...
# 2875916  I received these earlier than expected. Have r...
#
#                                                    summary
# 0                                        A  WONDERFUL BOOK
# 1                                                     Nice
# 2                                               Five Stars
# 3                         Good Reference in Kindle Edition
# 4                                Extremely clear, thorough
# ...                                                    ...
# 2875912  ... took weeks to arrive and ran out of ink pr...
# 2875913                                    Great product!!
# 2875914                                         Five Stars
# 2875915                                           One Star
# 2875916                                          One color
#
# [2872518 rows x 4 columns]

# %%
ans = [y for x, y in df.groupby('asin')]

# %%
ans[0]['reviewText']
# Out:
# 2129208    Great ribbon for wrapping gifts!
# Name: reviewText, dtype: object

# %%
print(len(ans))
# Out:
# 302718

# %%
for i in range (len(ans)):
  print(str(i) + " == " + str(len(ans[i])))
  if(len(ans[i])<1000):
    print(str(i) + " = " + str(len(ans[i])))
    ans.pop(i)
    i = i-3
# Out:
# 0 == 1262
# 1 == 1210
# 2 == 1932
# 3 == 1232
# 4 == 1216
# 5 == 2432
# 6 == 1464
# 7 == 1359
# 8 == 1641
# 9 == 2066
# 10 == 2097
# 11 == 1111
# 12 == 1431
# 13 == 3425
# 14 == 1428
# 15 == 1616
# 16 == 1788
# 17 == 1820
# 18 == 1155
# 19 == 1346
# 20 == 1058
# 21 == 2643
# 22 == 1601
# 23 == 1538
# 24 == 2380
# 25 == 1188
# 26 == 3590
# 27 == 1016
# 28 == 1028
# 29 == 1080
# 30 == 1280
# 31 == 1058
# 32 == 1192
# 33 == 1556
# 34 == 1138
# 35 == 2134
# 36 == 1744
# 37 == 3860
# 38 == 1310
# 39 == 1078
# 40 == 1598
# 41 == 1924
# 42 == 1232
# 43 == 1174
# 44 == 1210
# 45 == 1072
# 46 == 1290
# 47 == 3766
# 48 == 1626
# 49 == 1038
# 50 == 1276
# 51 == 1604
# 52 == 1118
# 53 == 1018
# 54 == 4002
# 55 == 1180
# 56 == 1118
# 57 == 1732
# 58 == 2612
# 59 == 1014
# 60 == 3858
# 61 == 1028
# 62 == 1134
# 63 == 1624
# 64 == 1492
# 65 == 2298
# 66 == 1524
# 67 == 1346
# 68 == 1928
# 69 == 1769
# 70 == 1586
# 71 == 1387
# 72 == 1818
# 73 == 1120
# 74 == 1985
# 75 == 1330
# 76 == 2506
# 77 == 2292
# 78 == 1809
# 79 == 1249
# 80 == 1469
# 81 == 2464
# 82 == 1007
# 83 == 1568
# 84 == 1008
# 85 == 4531
# 86 == 1445
# 87 == 1496
# 88 == 1174
# 89 == 1185
# 90 == 2211
# 91 == 1043
# 92 == 1253
# 93 == 3168
# 94 == 1746
# 95 == 1193
# 96 == 2635
# 97 == 1048
# 98 == 1444
# 99 == 1439
# 100 == 1048
# 101 == 1450
# 102 == 1151
# 103 == 1295
# 104 == 2952
# 105 == 1515
# 106 == 1579
# 107 == 1091
# 108 == 1162
# 109 == 1206
# 110 == 2500
# 111 == 1106
# 112 == 1597
# 113 == 1010
# 114 == 1435
# 115 == 2401
# 116 == 1117
# 117 == 1117
# 118 == 1239
# 119 == 1757
# 120 == 1012
# 121 == 1051
# 122 == 1151
# 123 == 1674
# 124 == 1242
# 125 == 1330
# 126 == 1611
# 127 == 1564
# 128 == 1858
# 129 == 1332
# 130 == 1519
# 131 == 1095
# 132 == 3056
# 133 == 1293
# 134 == 1187
# 135 == 1196
# 136 == 1456
# 137 == 1630
# 138 == 1975
# 139 == 1011
# 140 == 1611
# 141 == 1533
# 142 == 1208
# 143 == 1022
# 144 == 1608
# 145 == 1017
# 146 == 1097
# 147 == 1202
# 148 == 1892
# 149 == 2759

# %%
print(len(ans))
# Out:
# 150

# %%
for i in range (len(ans)):
  ans[i] = ans[i].reset_index()
  print(ans[i].head())
# Out:
#    level_0  index  overall        asin  \
# 0        0   5142        5  B00004THXH
# 1        1   5143        5  B00004THXH
# 2        2   5144        5  B00004THXH
# 3        3   5145        5  B00004THXH
# 4        4   5146        5  B00004THXH
#
#                                           reviewText  \
# 0  Back in the days when I was a student I used t...
# 1  This is a neat kit. I did replace one of the h...
# 2  I was going off to Art School and didn't have ...
# 3  This is the perfect watercolor box for artists...
# 4  These watercolor paints are great!  The case i...
#
#                        summary
# 0         Great for traveling.
# 1                Great product
# 2            Love These Paints
# 3    Perfect Gift for Artists!
# 4  Excellent Gift for Artists!
#    level_0  index  overall        asin  \
# 0        0  14210        4  B00006IFGJ
# 1        1  14211        5  B00006IFGJ
# 2        2  14212        4  B00006IFGJ
# 3        3  14213        3  B00006IFGJ
# 4        4  14214        5  B00006IFGJ
#
#                                           reviewText  \
# 0  As one of the top sellers in professional mark...
# 1  I purchased this set of markers for some story...
# 2  I've used these markers for a while now and th...
# 3  Prismacolors are nice markers. They aren't the...
# 4  If you are a hardcore traditional artist, or e...
#
#                                        summary
# 0                             Reliable markers
# 1             Easy use with excellent results.
# 2                   Really Good, for starters.
# 3             Nice Markers, a few downsides...
# 4  Nothing is perfect, but this is dang close!
#    level_0  index  overall        asin  \
# 0        0  22168        5  B0001DUD9O
# 1        1  22169        5  B0001DUD9O
# 2        2  22170        4  B0001DUD9O
# 3        3  22171        3  B0001DUD9O
# 4        4  22172        5  B0001DUD9O
#
#                                           reviewText                  summary
# 0          Very very great yarn .. I will order more              Pretty yarn
# 1                    Love this yarn. Love Red Heart.              Great yarn.
# 2  Loved it, fun colors. My husband calls it drag...              Fun colors.
# 3                                            matched              Three Stars
# 4  Love this yarn but have since found a lot chea...  better price at Walmart
#    level_0  index  overall        asin  \
# 0        0  29622        5  B00026ZEDK
# 1        1  29623        3  B00026ZEDK
# 2        2  29624        5  B00026ZEDK
# 3        3  29625        5  B00026ZEDK
# 4        4  29626        5  B00026ZEDK
#
#                                           reviewText  \
# 0  Bought this for my kids' shared birthday party...
# 1  If you are a beginner, or are just looking for...
# 2  It is such a big deal for children to have the...
# 3  My husband and I did face painting at our pres...
# 4  i actually am surprised with this product! I l...
#
#                                              summary
# 0                                       Easy and Fun
# 1                          You get what you pay for.
# 2  Excellent product - treat of the year for the ...
# 3                  Worked well for a preschool party
# 4                            Better than i expected!
#    level_0  index  overall        asin  \
# 0        0  37166        5  B0006Z5HSY
# 1        1  37167        5  B0006Z5HSY
# 2        2  37168        5  B0006Z5HSY
# 3        3  37169        5  B0006Z5HSY
# 4        4  37170        5  B0006Z5HSY
#
#                                           reviewText  \
# 0  I bought these identical markers 23 years ago ...
# 1  I got this set as a child and my mom recently ...
# 2  I bought a set of 36 colors before my son was ...
# 3  These are very nice pens.  The tips are fine e...
# 4  I like the sturdy, compact package these marke...
#
#                          summary
# 0            Outstanding product
# 1                 great markers!
# 2  Fantastic TOP QUALITY product
# 3                 Very Nice Pens
# 4        Pentel Fine-Tip Markers
#    level_0  index  overall        asin  \
# 0        0  45504        5  B000980L02
# 1        1  45505        5  B000980L02
# 2        2  45506        4  B000980L02
# 3        3  45507        5  B000980L02
# 4        4  45508        5  B000980L02
#
#                                           reviewText  \
# 0  It took me a long time to find end-caps that f...
# 1  The knitting bobbins I ordered arrived in a ve...
# 2  These work great for making fast pom-poms, as ...
# 3  I'm new to crocheting and really like the comf...
# 4  For the knitter who's just beginning this make...
#
#                                     summary
# 0                                   Finally
# 1                      Knitting experiences
# 2  Much faster than doing it the old way...
# 3              Awesome set of crochet hooks
# 4                   A fantastic starter kit
#    level_0  index  overall        asin  \
# 0        0  53786        5  B000A7JJF0
# 1        1  53787        5  B000A7JJF0
# 2        2  53788        5  B000A7JJF0
# 3        3  53789        5  B000A7JJF0
# 4        4  53790        5  B000A7JJF0
#
#                                           reviewText  \
# 0  This is a great product just got it today and ...
# 1  Just got this in yesterday, bought two of them...
# 2  This pad may be small, but I absolutely love i...
# 3  Very portable, easy to draw on, and the pages ...
# 4  just like the other reviewers said... so don't...
#
#                       summary
# 0     Good Sketch Book thingy
# 1                Good quality
# 2         Absolutely love it!
# 3                       Nifty
# 4  Awesome, daughter loves it
#    level_0  index  overall        asin  \
# 0        0  58441        4  B000B7K9UI
# 1        1  58442        5  B000B7K9UI
# 2        2  58443        5  B000B7K9UI
# 3        3  58444        5  B000B7K9UI
# 4        4  58445        5  B000B7K9UI
#
#                                           reviewText  \
# 0  I have used self healing mats before and this ...
# 1  The cutting mat size is perfect for a normal d...
# 2  I love it! absolutely love it! This is a sewer...
# 3  this is a helpful tool. I thought it was a lit...
# 4  For as much as I paid for this, I really expec...
#
#                         summary
# 0  Great for quilting beginners
# 1             Wonderful tools!!
# 2                a sewers dream
# 3                     it's good
# 4         Not very self healing
#    level_0  index  overall        asin  \
# 0        0  58451        5  B000B7M8WU
# 1        1  58452        4  B000B7M8WU
# 2        2  58453        5  B000B7M8WU
# 3        3  58454        5  B000B7M8WU
# 4        4  58455        4  B000B7M8WU
#
#                                           reviewText  \
# 0  I've always been a fan of any product of Fiska...
# 1  I use the rotary cutter to create a tear-along...
# 2  Being a person that loves to sew, I got this b...
# 3  This cutter fit the bill. We needed to perfora...
# 4  My rotary cutter has not seen a lot of use yet...
#
#                                              summary
# 0          Fiskar is the Cut of the Scissors ! (n_n)
# 1  create a dotted line for easy tearing of paper...
# 2                                              Great
# 3                                      Rotary Cutter
# 4                                 Very useful cutter
#    level_0  index  overall        asin  \
# 0        0  61137        5  B000B7Q9KM
# 1        1  61138        3  B000B7Q9KM
# 2        2  61139        3  B000B7Q9KM
# 3        3  61140        2  B000B7Q9KM
# 4        4  61141        5  B000B7Q9KM
#
#                                           reviewText  \
# 0  I must say, I am very pleasantly surprised at ...
# 1  I've always had good results with Rit liquid d...
# 2  Did not dye my item black. More of a grayish b...
# 3  made stuff grey n smelly, not black. probably ...
# 4  It works great, if you are dying something tha...
#
#                               summary
# 0       Great for dyeing auto carpet!
# 1  excellent dye, not excellent price
# 2                               Title
# 3                               oops!
# 4           Works great even on white
#    level_0  index  overall        asin  \
# 0        0  72062        5  B000BQKGR0
# 1        1  72063        5  B000BQKGR0
# 2        2  72064        5  B000BQKGR0
# 3        3  72065        3  B000BQKGR0
# 4        4  72066        5  B000BQKGR0
#
#                                           reviewText                 summary
# 0  This is the best glue I have EVER used to glue...  Glue to set dog's ears
# 1  For those interested in this product to use on...               Dog Eared
# 2  This is wonderful on jeans. It should not be u...             LOVE IT!!!!
# 3  I used this glue on my dog's ears.  I had gone...                    Glue
# 4  This is the only liquid fabric adhesive that I...           Awesome stuff
#    level_0  index  overall        asin  \
# 0        0  76549        3  B000BY4Q5K
# 1        1  76550        5  B000BY4Q5K
# 2        2  76551        5  B000BY4Q5K
# 3        3  76552        5  B000BY4Q5K
# 4        4  76553        4  B000BY4Q5K
#
#                                           reviewText  \
# 0  the yarn was good...can't go too wrong with ya...
# 1  This is rather soft and good feeling yarn. A c...
# 2  this product was easy to work with. Was a grea...
# 3  This yarn worked up really easy and grandkids ...
# 4  Arrived on time and in excellent condition. It...
#
#                               summary
# 0                The Yarn was good...
# 1  Good yarn, light weighted and soft
# 2                            purchase
# 3                            purchase
# 4                                Soft
#    level_0  index  overall        asin  \
# 0        0  83202        5  B000EOX28E
# 1        1  83203        1  B000EOX28E
# 2        2  83204        5  B000EOX28E
# 3        3  83205        5  B000EOX28E
# 4        4  83206        4  B000EOX28E
#
#                                           reviewText  \
# 0  I just bought this sewing machine for my 8 yr ...
# 1  Bought this machine for my youngest daughter a...
# 2                                     it work great.
# 3  First sewing machine I've ever used. After an ...
# 4  Brought this machine from a local store as I w...
#
#                         summary
# 0              Sewing made easy
# 1           not worth the money
# 2                    Five Stars
# 3  Good buy. Only one con noted
# 4                  Easy to use.
#    level_0  index  overall        asin  \
# 0        0  85849        4  B000F7DPEQ
# 1        1  85850        5  B000F7DPEQ
# 2        2  85851        4  B000F7DPEQ
# 3        3  85852        5  B000F7DPEQ
# 4        4  85853        5  B000F7DPEQ
#
#                                           reviewText                 summary
# 0  This is a great machine for the price.  I am t...    One major limitation
# 1  I bought this for my 11-year-old daughter.\nA ...            nice machine
# 2  I have had this machine for a few weeks now an...  Brother sewing machine
# 3  This machine is great!  I researched for month...           Great machine
# 4  This machine is just great for me.  I previous...    Sewing is fun again!
#    level_0  index  overall        asin  \
# 0        0  99917        5  B000H6OYSQ
# 1        1  99918        2  B000H6OYSQ
# 2        2  99919        4  B000H6OYSQ
# 3        3  99920        3  B000H6OYSQ
# 4        4  99921        3  B000H6OYSQ
#
#                                           reviewText  \
# 0  For those cosplaying Homestuck trolls, this st...
# 1  This face paint is pretty good; it lasts prett...
# 2  Face paint wise, I highly recommend this as it...
# 3  Face paint wise, I highly recommend this as it...
# 4  I love this face paint but the three times I h...
#
#                                              summary
# 0                                          oH WOW,,,
# 1              Product is good, but case is damaged.
# 2  Awesome product but be ware you check the sell...
# 3  Snazaroo rocks but be ware where you buy it fr...
# 4  Awesome product but be ware you check the sell...
#    level_0   index  overall        asin  \
# 0        0  534188        5  B000H6UNQI
# 1        1  534189        4  B000H6UNQI
# 2        2  534190        5  B000H6UNQI
# 3        3  534191        5  B000H6UNQI
# 4        4  534192        5  B000H6UNQI
#
#                                           reviewText  \
# 0  Perfect for Halloween. Used it for wicked witc...
# 1  I do facepainting from time to time, usually o...
# 2  This is the best face paint that I have found....
# 3  I bought the entire pallet and this is the one...
# 4  Didn't know what to expect as I'd never bought...
#
#                                   summary
# 0                    How green is my face
# 1  One of the best face paints out there.
# 2    Best face paint out there. *updated*
# 3                        Beautiful Color!
# 4                         Alien for a day
#    level_0   index  overall        asin  \
# 0        0  103314        5  B000HF6YX0
# 1        1  103315        5  B000HF6YX0
# 2        2  103316        3  B000HF6YX0
# 3        3  103317        2  B000HF6YX0
# 4        4  103318        3  B000HF6YX0
#
#                                           reviewText  \
# 0  This is a great acrylic paint set for someone ...
# 1  I love these paints...pure and simple.\n\nFor ...
# 2  The paint is great. I haven't opened every tub...
# 3  Nice colours however one color came in solid i...
# 4                 Blue came dry, the rest were fine.
#
#                                              summary
# 0                      A very good acrylic paint set
# 1                                                <3!
# 2                                               Good
# 3  Nice colours however one color came in solid i...
# 4                                       May come dry
#    level_0   index  overall        asin  \
# 0        0  105980        5  B000HTBBO8
# 1        1  105981        5  B000HTBBO8
# 2        2  105982        5  B000HTBBO8
# 3        3  105983        4  B000HTBBO8
# 4        4  105984        5  B000HTBBO8
#
#                                           reviewText             summary
# 0  I got this set for my nephew and was shocked a...           Great set
# 1  very nice drawing kit. came in the estimated t...         drawing kit
# 2  Honestly, I'm far from the best artist and wou...               Great
# 3  Really nice set for the price. A nice various ...        Really neat!
# 4  Shipping was surprisingly fast, packing was ne...  Gift for an artist
#    level_0   index  overall        asin  \
# 0        0  116606        5  B000JF2ZB8
# 1        1  116607        5  B000JF2ZB8
# 2        2  116608        4  B000JF2ZB8
# 3        3  116609        5  B000JF2ZB8
# 4        4  116610        4  B000JF2ZB8
#
#                                           reviewText  \
# 0      Park always has great quality tools and kits.
# 1  The patches themselves are extremely tough, no...
# 2  Takes some time to do the job so may not be th...
# 3  Just what I needed to patch a car inner tube I...
# 4  The kit looks good, it contains everything nee...
#
#                                  summary
# 0                              Great kit
# 1  High Quality Patch Kit from Park Tool
# 2                             works well
# 3         Excellent product! Works great
# 4    Seems good, waiting to test further
#    level_0   index  overall        asin  \
# 0        0  120717        5  B000KBH7S2
# 1        1  120718        5  B000KBH7S2
# 2        2  120719        4  B000KBH7S2
# 3        3  120720        5  B000KBH7S2
# 4        4  120721        5  B000KBH7S2
#
#                                           reviewText  \
# 0  Bought this for my son to repair his backpacki...
# 1     Who doesn't like tenacious tape in their pack?
# 2  My jacket tore which made me buy this and I fo...
# 3              gem of a product! easy and effective.
# 4                           Best gear tape there is.
#
#                                              summary
# 0                              Tenacious Repair Tape
# 1                                         Five Stars
# 2  ... which made me buy this and I found it usef...
# 3                                 easy and effective
# 4                                         Five Stars
#    level_0   index  overall        asin  \
# 0        0  142076        5  B000OML5OY
# 1        1  142147        5  B000OML5OY
# 2        2  142148        2  B000OML5OY
# 3        3  142149        4  B000OML5OY
# 4        4  142150        5  B000OML5OY
#
#                                           reviewText  \
# 0  I bought these beads just for the colors, just...
# 1                                    a lot of beads!
# 2  Despite being advertised at 9mm, these are mor...
# 3                                       good product
# 4  Very pretty & colorful beads! Best of all the ...
#
#                                        summary
# 0                         awesome kandi beads!
# 1                              a lot of beads!
# 2  these are more like 6. They're decent beads
# 3                                   Four Stars
# 4                                   Five Stars
#    level_0   index  overall        asin  \
# 0        0  147265        1  B000P0LNRE
# 1        1  147266        5  B000P0LNRE
# 2        2  147267        1  B000P0LNRE
# 3        3  147268        5  B000P0LNRE
# 4        4  147269        1  B000P0LNRE
#
#                                           reviewText                summary
# 0  At a well-known big box store last Christmas, ...    Buy Fiskars instead
# 1  I've been doing paper crafting for more than a...   Best of All the Rest
# 2  I have been buying these scissors for years at...  Good until they break
# 3  I gave these scissors to two left handed frien...     The Right Scissors
# 4  I seldom write reviews, but my experience with...          piece of junk
#    level_0   index  overall        asin  \
# 0        0  171149        3  B000SVRSRY
# 1        1  171150        5  B000SVRSRY
# 2        2  171151        4  B000SVRSRY
# 3        3  171152        4  B000SVRSRY
# 4        4  171153        4  B000SVRSRY
#
#                                           reviewText  \
# 0  I like the variety of ends and possible uses. ...
# 1  Awesome set here. I bought them for a sculptur...
# 2  This is actually a set of wax carving tools.  ...
# 3  I purchased this to use for creating designs i...
# 4  the twelve piece set i recieved is pretty good...
#
#                           summary
# 0                These guys rust!
# 1                    Sweet set!!!
# 2             Good deal for the $
# 3          Great jewelry wax tool
# 4  wax carving tools/dental tools
#    level_0   index  overall        asin  \
# 0        0  176705        5  B000UU6SR4
# 1        1  176706        5  B000UU6SR4
# 2        2  176707        5  B000UU6SR4
# 3        3  176708        5  B000UU6SR4
# 4        4  176709        5  B000UU6SR4
#
#                                           reviewText  \
# 0  My wife has her own assortment or nice scissor...
# 1  I had purchased this for my girlfriend for Chr...
# 2  It cuts through multiple pieces of fabric clea...
# 3  I actually bought these scissors as a replacem...
# 4  A winner. To me, they are by far superior to M...
#
#                                              summary
# 0                           Good quality, good value
# 1                              Cheaper than expected
# 2  If there are heirloom scissors, these would be...
# 3                                wonderful scissors!
# 4      Gingher G-8 8-Inch Knife-Edge Dressmaker's...
#    level_0   index  overall        asin  \
# 0        0  184110        5  B000W5R6UA
# 1        1  184111        2  B000W5R6UA
# 2        2  184112        5  B000W5R6UA
# 3        3  184113        4  B000W5R6UA
# 4        4  184114        5  B000W5R6UA
#
#                                           reviewText  \
# 0  They are stiffer than the pipe cleaners you bu...
# 1  Got these to clean AR/15 gas tube found to be ...
# 2  I am very happy with the way you responded to ...
# 3  Before I bought these pipe cleaners, I used Pe...
# 4  If you think all pipe cleaners are alike you'r...
#
#                         summary
# 0          Perfect for the job!
# 1        NOT FOR AR/15 PLATFORM
# 2                    Items sent
# 3  Close to perfect. Very close
# 4             Zen Pipe Cleaners
#    level_0   index  overall        asin  \
# 0        0  185821        5  B000WDTVIC
# 1        1  185822        5  B000WDTVIC
# 2        2  185823        5  B000WDTVIC
# 3        3  185824        5  B000WDTVIC
# 4        4  185825        5  B000WDTVIC
#
#                                           reviewText  \
# 0  I have bought tearaway stabilizer before that ...
# 1  I ordered this for my Wife, and she says this ...
# 2  A bit stiffer than the others I have used but ...
# 3  This product works great with my sewing machin...
# 4  I go through a lot of tear away, so when I ran...
#
#                       summary
# 0           Easily Tears Away
# 1   Much Better Than Cutting!
# 2        well worth the money
# 3             Excellent value
# 4  Great Value for tear away!
#    level_0   index  overall        asin  \
# 0        0  187898        2  B000WOM50W
# 1        1  187899        5  B000WOM50W
# 2        2  187900        5  B000WOM50W
# 3        3  187901        3  B000WOM50W
# 4        4  187902        5  B000WOM50W
#
#                                           reviewText  \
# 0  This case was really big.  It was twice as lar...
# 1  I just received my Singer 611 universal case. ...
# 2  This case is a extremely sturdy case and an ex...
# 3  Purchased for new machine to allow for storage...
# 4  I got this case for my Singer 7442 sewing mach...
#
#                                            summary
# 0                                       VERY large
# 1                              SEWING MACHINE CASE
# 2  universal hard singer sewing machine case 611BR
# 3               All Purpose Case - Singer Machines
# 4                 A good sturdy case for my Singer
#    level_0   index  overall        asin  \
# 0        0  189701        4  B000WOV83M
# 1        1  189702        4  B000WOV83M
# 2        2  189703        5  B000WOV83M
# 3        3  189704        4  B000WOV83M
# 4        4  189705        1  B000WOV83M
#
#                                           reviewText  \
# 0  This is a must have.  There are some down side...
# 1  My husband surprised me with a Cricut for Chri...
# 2  I purchased the Cricut Expression after testin...
# 3  This is one of those products that could have ...
# 4    Took a month to ship it out and it didn't work.
#
#                                  summary
# 0                       Great but.......
# 1           Love it, but has limitations
# 2  Absolutely Love My Cricut Expression!
# 3                Little Expensive but...
# 4              I highly recommend....Not
#    level_0   index  overall        asin  \
# 0        0  190509        4  B000WURGNC
# 1        1  190510        4  B000WURGNC
# 2        2  190511        3  B000WURGNC
# 3        3  190512        4  B000WURGNC
# 4        4  190513        4  B000WURGNC
#
#                                           reviewText  \
# 0  This is a great set of needles.  The case is w...
# 1  I bought this set (using a coupon at a craft s...
# 2  I got this set when I first started knitting a...
# 3  The joins between the needles and cord were ro...
# 4  Have had these for years, I think they're unde...
#
#                                              summary
# 0                                      Love this set
# 1               Economical and simple for beginners.
# 2                  okay needles, but there is better
# 3  The joins between the needles and cord were ro...
# 4                     Really solid set for the price
#    level_0   index  overall        asin  \
# 0        0  192242        5  B000WUXO4W
# 1        1  192243        5  B000WUXO4W
# 2        2  192244        5  B000WUXO4W
# 3        3  192245        5  B000WUXO4W
# 4        4  192246        5  B000WUXO4W
#
#                                           reviewText  \
# 0  Absolutely love the mini kacha-kacha; with loc...
# 1  This is a great stitch counter for carrying ar...
# 2  I bought the Kacha because a friend recommende...
# 3  I was a little skeptical about the quality of ...
# 4  I have several types of counters for my knitti...
#
#                         summary
# 0                       love it
# 1          Handy Stitch Counter
# 2           Great Knitting Tool
# 3          Clearly High Quality
# 4  Locking feature is worth it!
#    level_0   index  overall        asin  \
# 0        0  190798        4  B000WUXOT2
# 1        1  190799        1  B000WUXOT2
# 2        2  190800        5  B000WUXOT2
# 3        3  190801        2  B000WUXOT2
# 4        4  190802        5  B000WUXOT2
#
#                                           reviewText  \
# 0  This stone works so much better than the other...
# 1  I bought this product so I could save on batte...
# 2  worked great - just use it outside so that you...
# 3  I was asked twice to review this product.  It ...
# 4  I'm very pleased with the sweater stone.  I us...
#
#                                            summary
# 0                                     Works great!
# 1  Doesn't work. Not even worth it if it was $1.00
# 2                                            works
# 3                             Did not work for me.
# 4                                   great purchase
#    level_0   index  overall        asin  \
# 0        0  195470        1  B000WWK8US
# 1        1  195471        5  B000WWK8US
# 2        2  195472        4  B000WWK8US
# 3        3  195473        3  B000WWK8US
# 4        4  195474        4  B000WWK8US
#
#                                           reviewText  \
# 0  when i was reading comments, i was thinking: I...
# 1  Been using these for several months now, they ...
# 2  Matched my expectations.  I did discover that ...
# 3  I received the package within a few days of or...
# 4  The product was what the descrition said it wa...
#
#                         summary
# 0                  not so happy
# 1                        Solid.
# 2                   Punch Happy
# 3               Not as expected
# 4  Accurate product description
#    level_0   index  overall        asin  \
# 0        0  201443        3  B000XANNVA
# 1        1  201444        4  B000XANNVA
# 2        2  201445        4  B000XANNVA
# 3        3  201446        5  B000XANNVA
# 4        4  201447        5  B000XANNVA
#
#                                           reviewText  \
# 0  Not sure if it's just in my head, but the shar...
# 1  As my title states, this product is necessary ...
# 2  The product works great -- arrived on-time, as...
# 3  It is full of lots of fun new images that I co...
# 4  If you own a cricut, new blades are a must hav...
#
#                       summary
# 0            Luck of the draw
# 1  Necessary for using Cricut
# 2       Excellent service....
# 3                  Love it!!!
# 4                 A must have
#    level_0   index  overall        asin  \
# 0        0  202786        5  B000XAPLKQ
# 1        1  202787        4  B000XAPLKQ
# 2        2  202788        5  B000XAPLKQ
# 3        3  202833        5  B000XAPLKQ
# 4        4  202834        4  B000XAPLKQ
#
#                                           reviewText  \
# 0  These scissors are awesome. I do a lot of sewi...
# 1  These scissors are real nice.  I have not had ...
# 2  I had a set of 8" Fiskars for years and that p...
# 3  Quick delivery.  Long lasting.  Made well and ...
# 4  The scissors are fine, sharp as can be...\nThe...
#
#                                              summary
# 0                                   Awesome scissors
# 1                                               nice
# 2                  Redesigned and better than before
# 3                                    They are sharp!
# 4  Nothing wrong with the product, it's great - b...
#    level_0   index  overall        asin  \
# 0        0  205536        5  B000XE3FGO
# 1        1  205537        5  B000XE3FGO
# 2        2  205538        5  B000XE3FGO
# 3        3  205539        5  B000XE3FGO
# 4        4  205540        5  B000XE3FGO
#
#                                           reviewText  \
# 0  I am really happy with my machine.  I have bee...
# 1  Love it! I enjoy sewing with this machine due ...
# 2  This is an amazing sewing machine that anyone ...
# 3  I love, love, love this sewing machine.  It is...
# 4  I recently purchased this machine because I ne...
#
#                            summary
# 0    I love my new sewing machine!
# 1        Excellent Machine! Crisp!
# 2                   A Must Have!!!
# 3                    Great Machine
# 4  Excellent Product for the price
#    level_0   index  overall        asin  \
# 0        0  210860        5  B000XZY8H8
# 1        1  210861        1  B000XZY8H8
# 2        2  210862        1  B000XZY8H8
# 3        3  210953        5  B000XZY8H8
# 4        4  210954        5  B000XZY8H8
#
#                                           reviewText  \
# 0  I <3 Red Heart Yarns. I've used them forever w...
# 1  On the page for this yarn the color showed as ...
# 2  I was looking to buy maybe a case of this yard...
# 3                                       Good quality
# 4        Red Heart yarn is one of my favorite yarns.
#
#                                  summary
# 0  Straight to the "Heart" of the Matter
# 1                   Advertising is false
# 2                     cheaper at walmart
# 3                             Five Stars
# 4                               Love it.
#    level_0   index  overall        asin  \
# 0        0  210811        5  B000XZYISM
# 1        1  210812        5  B000XZYISM
# 2        2  210813        3  B000XZYISM
# 3        3  210814        5  B000XZYISM
# 4        4  210815        5  B000XZYISM
#
#                                           reviewText  \
# 0  Susan Bates is my preferred manufacturer of ho...
# 1  I've used many types of crochet hooks over the...
# 2  I bought both the Susan Bates hook sets awhile...
# 3  These are the best crochet hooks around, and t...
# 4  I bought this as a gift for my best friend who...
#
#                                         summary
# 0                       Excellent Crochet Hooks
# 1  Susan Bates Silvalume Crochet Hook on Amazon
# 2     Good for beginners, Bad for everyone else
# 3                            BEST crochet hooks
# 4                                  A great gift
#    level_0   index  overall        asin  \
# 0        0  209983        5  B000Y00DDK
# 1        1  209984        5  B000Y00DDK
# 2        2  209985        5  B000Y00DDK
# 3        3  209986        4  B000Y00DDK
# 4        4  209987        3  B000Y00DDK
#
#                                           reviewText      summary
# 0                  Very pleased with this purchase!!   Five Stars
# 1          Very very great yarn .. I will order more  Pretty yarn
# 2                    Love this yarn. Love Red Heart.  Great yarn.
# 3  Loved it, fun colors. My husband calls it drag...  Fun colors.
# 4                                            matched  Three Stars
#    level_0   index  overall        asin  \
# 0        0  217333        4  B000YAAGX2
# 1        1  217334        5  B000YAAGX2
# 2        2  217335        5  B000YAAGX2
# 3        3  217336        5  B000YAAGX2
# 4        4  217337        5  B000YAAGX2
#
#                                           reviewText            summary
# 0  I actually bought this on a whim at CVS (pharm...  Well worth $10!!!
# 1  This is a great product.  It works great on bo...      Great product
# 2                                 Works really well.         Five Stars
# 3  I love this thing! It uses regular size batter...      Great product
# 4                                      Handy gadget.         Five Stars
#    level_0   index  overall        asin  \
# 0        0  226155        4  B000YZ45G6
# 1        1  226156        4  B000YZ45G6
# 2        2  226157        1  B000YZ45G6
# 3        3  226158        4  B000YZ45G6
# 4        4  226217        5  B000YZ45G6
#
#                                           reviewText  \
# 0  This is a nice box but I also got the Dritz bo...
# 1  It holds all my empty and prewound bobbins nic...
# 2  the picture is disieving.... I thought it came...
# 3  It is a good box to keep bobbins. But when I o...
# 4  This ArtBin Bobbin Box is a great size and ver...
#
#                                             summary
# 0                                    Bin Bobbin Box
# 1                                 does what it says
# 2                       high price for an empty box
# 3  good box for bobbins.  Bibbins are not included.
# 4                                  Handy Bobbin Box
#    level_0   index  overall        asin  \
# 0        0  228380        5  B000YZ5NJE
# 1        1  228381        4  B000YZ5NJE
# 2        2  228382        5  B000YZ5NJE
# 3        3  228383        1  B000YZ5NJE
# 4        4  228384        3  B000YZ5NJE
#
#                                           reviewText  \
# 0  These are great needles.  I got them 3 days af...
# 1  same as any other needle,. bought with sewing ...
# 2  They are needles and they work. However, they ...
# 3  Bought the 10 pack from my local craft store. ...
# 4  I have tried Singer Universal Regular Point Ma...
#
#                       summary
# 0               great needles
# 1               sewing needle
# 2  They Work - Their Needles!
# 3                  DO NOT BUY
# 4           OK, but not great
#    level_0   index  overall        asin  \
# 0        0  231774        4  B000YZAO2K
# 1        1  231775        5  B000YZAO2K
# 2        2  231776        4  B000YZAO2K
# 3        3  231777        5  B000YZAO2K
# 4        4  231778        4  B000YZAO2K
#
#                                           reviewText  \
# 0  I'm an architect student, and I come to certai...
# 1  There is nothing extraneous.\n\nNo irritating ...
# 2  It's 60 inches in case anyone was wondering, I...
# 3  Although I have not used many tape measures be...
# 4  The clover "Shiro" Tape Measure is a handy dev...
#
#                                           summary
# 0                             Really nice product
# 1  great compact timeless design and construction
# 2                      decent little tape measure
# 3                         Excellent Tape Measure.
# 4             Lightweight-- handy for portability
#    level_0   index  overall        asin  \
# 0        0  235594        5  B000YZASYO
# 1        1  235595        5  B000YZASYO
# 2        2  235646        5  B000YZASYO
# 3        3  235647        5  B000YZASYO
# 4        4  235648        5  B000YZASYO
#
#                                           reviewText  \
# 0  This mat is incredible. It has held up to my r...
# 1  I needed a large self healing cutting mat to g...
# 2  Love this mat. So easy to read and holds up gr...
# 3                    Great size for larger projects.
# 4                                              GREAT
#
#                                           summary
# 0                                  Fantastic mat!
# 1  Right item at the right price received on time
# 2                          Double sided is great.
# 3                                      Five Stars
# 4                                      Five Stars
#    level_0   index  overall        asin  \
# 0        0  241643        5  B0010TEFFQ
# 1        1  241644        5  B0010TEFFQ
# 2        2  241645        5  B0010TEFFQ
# 3        3  241646        5  B0010TEFFQ
# 4        4  241647        5  B0010TEFFQ
#
#                                           reviewText  \
# 0  This is just a great product!  Yes, I work in ...
# 1  Create, explore and enjoy and then watch it al...
# 2  Great, fun product.  My mother is from Japan a...
# 3  The Buddha Board is on my kitchen counter, and...
# 4  I would recommend this as a gift or for yourse...
#
#                                              summary
# 0                                         LOVED it!!
# 1                              Impermanence Training
# 2                                       Buddha Board
# 3  This is a great art form for anyone, regardles...
# 4                                         Worth It!!
#    level_0   index  overall        asin  \
# 0        0  242852        5  B001144TXI
# 1        1  242863        1  B001144TXI
# 2        2  242864        3  B001144TXI
# 3        3  242865        3  B001144TXI
# 4        4  242866        1  B001144TXI
#
#                                           reviewText  \
# 0  Like the product and went well when doing it. ...
# 1  I bought this "kit" for my 8 year old daughter...
# 2                                      No color code
# 3  Its a good deal for price... Was disappointed ...
# 4  The picture and the project do not match up! T...
#
#                                              summary
# 0                                            unicorn
# 1  No Latch Hook Tool and Canvas is rough, imposs...
# 2                                      No color code
# 3                          Its a good deal for price
# 4   The picture and the project do not match up! ...
#    level_0   index  overall        asin  \
# 0        0  246826        3  B00114OS84
# 1        1  246882        3  B00114OS84
# 2        2  246883        1  B00114OS84
# 3        3  246884        3  B00114OS84
# 4        4  246885        3  B00114OS84
#
#                                           reviewText  \
# 0  The assembly instructions for this product are...
# 1                         Too flimsy for large items
# 2                                          Terrible.
# 3  It was awkward to put together and its a littl...
# 4  We used them at the university for poster pres...
#
#                                              summary
# 0                                                Meh
# 1                                        Three Stars
# 2                                           One Star
# 3                                    It does the job
# 4  They do not fold up very easily - as a matter ...
#    level_0   index  overall        asin  \
# 0        0  250980        5  B00114RIIQ
# 1        1  250981        5  B00114RIIQ
# 2        2  250982        1  B00114RIIQ
# 3        3  251023        5  B00114RIIQ
# 4        4  251024        5  B00114RIIQ
#
#                                           reviewText  \
# 0  My 3rd grader's teacher studied different arti...
# 1  Ah. I love these paints. They're wonderful to ...
# 2  The original title of this item was "Brush Tub...
# 3  I have purchased this brand before and am alwa...
# 4  This box is just perfect of holding my paint s...
#
#                          summary
# 0         My Daughter LOVES them
# 1   Simply Art: Watercolor Cakes
# 2  Wrong Tub, Misleading Picture
# 3                Great brush tub
# 4                     Five Stars
#    level_0   index  overall        asin  \
# 0        0  256733        5  B00122CN64
# 1        1  256734        5  B00122CN64
# 2        2  256735        5  B00122CN64
# 3        3  256736        5  B00122CN64
# 4        4  256737        2  B00122CN64
#
#                                           reviewText  \
# 0  I love the waterbrush in this, which means you...
# 1  This is my first watercolor paint set. Frankly...
# 2  I own this Koi watercolor kit. I truly love it...
# 3  I was looking for this before I knew it existe...
# 4  These are often recommended a good starter stu...
#
#                                              summary
# 0                               Great kit for travel
# 1                                        Really Cool
# 2  Looking for something great and practical? ......
# 3                         very useful for watercolor
# 4  These are often recommended a good starter stu...
#    level_0   index  overall        asin  \
# 0        0  262579        5  B00138ZNSC
# 1        1  262580        4  B00138ZNSC
# 2        2  262581        4  B00138ZNSC
# 3        3  262582        5  B00138ZNSC
# 4        4  262583        5  B00138ZNSC
#
#                                           reviewText                summary
# 0  I saw this same product for about $25.  It was...           Worked great
# 1  like everyone mentioned color is hard to mix b...  good quality touch up
# 2  When I bought this item, the only way I had an...  tricky, but it worked
# 3  This product is easy to use and works great......      Works great......
# 4  This is a great kit. One, you can repair a scu...   Repairs and recolors
#    level_0   index  overall        asin  \
# 0        0  264688        5  B0013CDJTS
# 1        1  264689        3  B0013CDJTS
# 2        2  264690        3  B0013CDJTS
# 3        3  264691        5  B0013CDJTS
# 4        4  264692        4  B0013CDJTS
#
#                                           reviewText  \
# 0  I have to admit I've never touched the stuff, ...
# 1  This pack has a great color selection but the ...
# 2  This is not much heavier than printer paper - ...
# 3  While this is not, as other reviewers have men...
# 4  This is not your heavy duty construction paper...
#
#                                              summary
# 0                                        It's paper.
# 1                     Lots of Colors, but thin paper
# 2               Not your standard construction paper
# 3  Awesome Value!!! Great 'daily use' Constructio...
# 4                            Great Price, Good Paper
#    level_0   index  overall        asin  \
# 0        0  265291        5  B0013D53CS
# 1        1  265292        5  B0013D53CS
# 2        2  265293        5  B0013D53CS
# 3        3  265294        4  B0013D53CS
# 4        4  265295        4  B0013D53CS
#
#                                           reviewText  \
# 0  I've used Testers glue for decades, I use to l...
# 1  Testors has always been a great company. This ...
# 2  Well, its glue and it does just that. However,...
# 3  This very good glue for models,but only use th...
# 4  Ah model glue. Nothing brings back memories of...
#
#                            summary
# 0               Tester is the best
# 1                       Great Glue
# 2                      works great
# 3  Stickier than white on rice!!!!
# 4              Time Tested Testors
#    level_0   index  overall        asin  \
# 0        0  267561        5  B0013JRFUA
# 1        1  267562        2  B0013JRFUA
# 2        2  267563        5  B0013JRFUA
# 3        3  267564        5  B0013JRFUA
# 4        4  267565        5  B0013JRFUA
#
#                                           reviewText  \
# 0  I had been searching for chip board for projec...
# 1  It's too thick for my intended uses in scrapbo...
# 2  I do one stroke painting and these shipboard p...
# 3  This is the second time I have ordered this ch...
# 4  Well, it came looking exactly as I expected. W...
#
#                       summary
# 0                   Chipboard
# 1  Too Thick for Scrapbooking
# 2                   chipboard
# 3        Love this chipboard!
# 4         What to do with it?
#    level_0   index  overall        asin  \
# 0        0  271121        4  B0013UD43Q
# 1        1  271122        5  B0013UD43Q
# 2        2  271123        5  B0013UD43Q
# 3        3  271124        5  B0013UD43Q
# 4        4  271125        4  B0013UD43Q
#
#                                           reviewText  \
# 0  This is a really nice bench block but I wish I...
# 1  I chose to get this size anvil even after all ...
# 2  This 4x4 steel bench block arrived quickly and...
# 3  This item came in several dollars less then ot...
# 4  Ideally, you want a piece of 4" by 4" top qual...
#
#                                              summary
# 0  Nice but I wish I had gotten the one with the ...
# 1                                 Gets the job done!
# 2                                     No complaints.
# 3                        Bench block at a good price
# 4                                Good low cost anvil
#    level_0   index  overall        asin  \
# 0        0  271655        5  B0013UDWXI
# 1        1  271656        5  B0013UDWXI
# 2        2  271657        5  B0013UDWXI
# 3        3  271658        5  B0013UDWXI
# 4        4  271679        5  B0013UDWXI
#
#                                           reviewText              summary
# 0  The clay is super amazing! It air dries so you...       Amazing stuff!
# 1  I just got back into modeling about a year ago...       Awesome stuff!
# 2  This is truly an amazing product. Ive used it ...  Top Quality Product
# 3  Great for modeling, the fact that it sands dow...           Good Stuff
# 4           Easy to work with. Worked as advertised.           Five Stars
#    level_0   index  overall        asin  \
# 0        0  274587        5  B0014DGXU8
# 1        1  274588        2  B0014DGXU8
# 2        2  274589        5  B0014DGXU8
# 3        3  274590        3  B0014DGXU8
# 4        4  274591        1  B0014DGXU8
#
#                                           reviewText  \
# 0  I was skeptical about Ring Snuggies after read...
# 1  My rings are loose on me and can slide off.  I...
# 2  Comfortable when on my ring on my finger. Thes...
# 3  I do end up using one of the ring snuggies tha...
# 4  Too stiff to get around my ring. Not good for ...
#
#                                              summary
# 0                         Very pleasantly surprised!
# 1                                         Not great.
# 2                          Now I won't lose my ring!
# 3     helpful, but not quite as nice as I was hoping
# 4  Not good for rings that are just a hair too large
#    level_0   index  overall        asin  \
# 0        0  276848        5  B0014OE08E
# 1        1  276849        5  B0014OE08E
# 2        2  276850        2  B0014OE08E
# 3        3  276851        4  B0014OE08E
# 4        4  276852        5  B0014OE08E
#
#                                           reviewText  \
# 0  The body is a hard material under the cover.  ...
# 1  Works great in my store.  The white 'slip cove...
# 2  i got this dress form a while ago and i like i...
# 3  The dress form arrives today and it is a dress...
# 4  this is the best dress form you can find for t...
#
#                                              summary
# 0                            Exactly what I expected
# 1                                           Great!!!
# 2                                    not that sturdy
# 3  Expeting a White dress form and It is a BLACK ...
# 4                                           perfect!
#    level_0   index  overall        asin  \
# 0        0  279733        5  B0015ZYXW0
# 1        1  279734        4  B0015ZYXW0
# 2        2  279735        5  B0015ZYXW0
# 3        3  279736        5  B0015ZYXW0
# 4        4  279737        5  B0015ZYXW0
#
#                                           reviewText  \
# 0  Not much needs to be said about Velcro, so I'l...
# 1  The product works great and I love being able ...
# 2  On a carving the person wanting it had to have...
# 3  I purchased these for a very specific purpose,...
# 4  I got these to use when making PECS pictures f...
#
#                                              summary
# 0  It meant what it said and it said what it mean...
# 1             Works great, dispenser could be better
# 2                                        worked fine
# ...
# 3        3  1531618        3  B00V4EG6D6
# 4        4  1531619        4  B00V4EG6D6
#
#                                           reviewText               summary
# 0        Great brushes for all that I need them for!         Paint brushes
# 1                 Great product and easy delivery !!            Five Stars
# 2            The blue sealant flakes off the brushes           Three Stars
# 3  They started off nice and worked perfect for p...  Get what you pay for
# 4                       Good product and good price.            Four Stars
#    level_0    index  overall        asin  \
# 0        0  1554731        5  B00WW8KIRI
# 1        1  1554732        5  B00WW8KIRI
# 2        2  1554733        5  B00WW8KIRI
# 3        3  1554734        5  B00WW8KIRI
# 4        4  1554735        5  B00WW8KIRI
#
#                                           reviewText                  summary
# 0  I love this stuff.  It's so easy to use, and i...  Best stuff in the world
# 1  I purchased Sugru with a few projects in mind....               Sugru Love
# 2  This stuff is terrific. It does what the maker...             SUGRU SRULES
# 3  This stuff is great......if you need something...              Fantastic!!
# 4  If you need to do little electrical or waterpr...      Great stuff! But...
#    level_0    index  overall        asin  \
# 0        0  1558456        5  B00WZ6N1QW
# 1        1  1558457        5  B00WZ6N1QW
# 2        2  1558458        4  B00WZ6N1QW
# 3        3  1558459        5  B00WZ6N1QW
# 4        4  1558460        4  B00WZ6N1QW
#
#                                           reviewText                summary
# 0  Easy to melt! Easy to pour. Good stuff! I real...                Awesome
# 1  Find an electric skillet at a thrift store-fin...  Soy Wax Batik Artists
# 2  This was my first time making candles, and thi...                Soy Wax
# 3  I am new to the whole candle making but I have...   No complaints here!!
# 4  It's a very good wax for container candles!\nN...           Soy 444 10lb
#    level_0    index  overall        asin  \
# 0        0  1574669        5  B00Y7QWHUO
# 1        1  1574670        5  B00Y7QWHUO
# 2        2  1574671        5  B00Y7QWHUO
# 3        3  1574672        5  B00Y7QWHUO
# 4        4  1574673        5  B00Y7QWHUO
#
#                                           reviewText  \
# 0  I have used crochet hooks in the past, and the...
# 1  I am definitely new to crocheting, I briefly l...
# 2  very comfortable needles.\nI recommend this to...
# 3  My mother has been crocheting for years. She h...
# 4  I've been having trouble crocheting for long p...
#
#                                              summary
# 0                                         Great Kit!
# 1                                      Beautiful set
# 2                        Comtortable Crochet needles
# 3  My mother loved these so much that she tried t...
# 4                             Great fit in your hand
#    level_0    index  overall        asin  \
# 0        0  1605743        5  B01178RVI2
# 1        1  1605744        4  B01178RVI2
# 2        2  1605745        1  B01178RVI2
# 3        3  1605746        5  B01178RVI2
# 4        4  1605747        5  B01178RVI2
#
#                                           reviewText  \
# 0  This glue gun is perfect for the price! You wi...
# 1    Works well but it is a little on the leaky side
# 2  CCbetter bribing people for good reviews. Quot...
# 3  PROS: Attached stand. ON/OFF switch! Super com...
# 4                                   Great little gun
#
#                                  summary
# 0                    Little but perfect!
# 1                             Four Stars
# 2  Poor product design and shady seller.
# 3     At $11 and change this is a Steal!
# 4                             Five Stars
#    level_0    index  overall        asin  \
# 0        0  1666077        1  B016MB0JF6
# 1        1  1666078        5  B016MB0JF6
# 2        2  1666079        5  B016MB0JF6
# 3        3  1666080        1  B016MB0JF6
# 4        4  1666081        5  B016MB0JF6
#
#                                           reviewText  \
# 0                           It did not adhere at all
# 1  Found a great use! Have a stone fireplace wall...
# 2  Love it!  Works great and at a fraction of the...
# 3  Smells like a toxic super glue even through th...
# 4  I used this to fix a small screwdriver--and it...
#
#                          summary
# 0                       One Star
# 1          Great problem solver!
# 2                          Happy
# 3  Did not work. Waste of money.
# 4                   5 second fix
#    level_0    index  overall        asin  \
# 0        0  1689807        5  B017Y20RI6
# 1        1  1689808        5  B017Y20RI6
# 2        2  1689809        5  B017Y20RI6
# 3        3  1689810        5  B017Y20RI6
# 4        4  1689811        3  B017Y20RI6
#
#                                           reviewText  \
# 0  This paper is very thick. It works really well...
# 1  Product came on time and it was exactly as des...
# 2  Arrived in a timely manner and nicely packaged...
# 3  It works great!! I am currently working on dec...
# 4  I wish the description noted that this paper i...
#
#                                              summary
# 0  It works really well and the grid lines are on...
# 1  Very happy to get a great product at a great p...
# 2  Arrived in a timely manner and nicely packaged...
# 3                                       Works great!
# 4  Great paper for vinyl transfer but NOT clear FYI.
#    level_0    index  overall        asin  \
# 0        0  1702503        5  B018PIF25G
# 1        1  1702504        5  B018PIF25G
# 2        2  1702505        4  B018PIF25G
# 3        3  1702506        5  B018PIF25G
# 4        4  1702507        5  B018PIF25G
#
#                                           reviewText  \
# 0                                            love it
# 1  Very nice pen set. I used every piece , all go...
# 2  I have purchased several sets of gel pens rece...
# 3  I was a little concerned about buying this but...
# 4  Amazing all are great colors. Only problem I h...
#
#                                              summary
# 0                                         Five Stars
# 1                                  Very nice pen set
# 2  ... gel pens recently as my daughter and I rea...
# 3                                        Very happy.
# 4                                47 different colors
#    level_0    index  overall        asin  \
# 0        0  1708335        5  B0190DAES0
# 1        1  1708336        5  B0190DAES0
# 2        2  1708337        5  B0190DAES0
# 3        3  1708338        5  B0190DAES0
# 4        4  1708339        5  B0190DAES0
#
#                                           reviewText  \
# 0  These pens are amazingly smooth and the glitte...
# 1  Have gotten into adult coloring and these pens...
# 2  I'll admit it. I have jumped on the adult colo...
# 3  I got these glitter gel pens as a little surpr...
# 4  These are great pens. I usually like to have c...
#
#                                 summary
# 0                       Wonderful pens!
# 1                           Lots of fun
# 2  great to use on adult coloring books
# 3           Vibrant, shimmery gel pens!
# 4        My favorite color is "SPARKLE"
#    level_0    index  overall        asin  \
# 0        0  1780709        4  B01D3MWPU4
# 1        1  1780710        5  B01D3MWPU4
# 2        2  1780711        4  B01D3MWPU4
# 3        3  1780712        2  B01D3MWPU4
# 4        4  1780713        5  B01D3MWPU4
#
#                                           reviewText  \
# 0  I am a firm believer that you get what you pay...
# 1  Purchased this as a Christmas gift for my son ...
# 2  I bought this to sew some car seat covers.  I ...
# 3  after a large project i have determined that t...
# 4  Have been sewing since I was 8 years old and h...
#
#                                summary
# 0             Fills the Gap I Intended
# 1       Very Please with This Purchase
# 2  "heavy duty" is possibly misleading
# 3   disappointment after large project
# 4                 LOVE SINGER PRODUCTS
#    level_0    index  overall        asin  \
# 0        0  1782370        5  B01D3VCTKG
# 1        1  1782371        5  B01D3VCTKG
# 2        2  1782372        5  B01D3VCTKG
# 3        3  1782373        5  B01D3VCTKG
# 4        4  1782374        5  B01D3VCTKG
#
#                                           reviewText  \
# 0  <div id="video-block-RC0OUBWGGTRK5" class="a-s...
# 1  Love the color variety. Do check your surfaces...
# 2                                        Great pens!
# 3  Colors are vibrant. They have worked well for ...
# 4  OMG I love these. I love the colors. The label...
#
#                                              summary
# 0                               I love these so much
# 1                                      Great product
# 2                                         Loved them
# 3                         Just what I was expecting.
# 4  Awesome product. You have to try these. great ...
#    level_0    index  overall        asin  \
# 0        0  1817562        5  B01EVJ8Q0G
# 1        1  1817563        5  B01EVJ8Q0G
# 2        2  1817564        5  B01EVJ8Q0G
# 3        3  1817565        5  B01EVJ8Q0G
# 4        4  1817566        5  B01EVJ8Q0G
#
#                                           reviewText                   summary
# 0     Fast shipment. This is exactly what we needed.                Five Stars
# 1  I love this paint! the consistency is thick , ...         I love this paint
# 2  Paint said had bright colors that worked well ...         Great for crafts!
# 3  My granddaughter loves these paints! Delivered...  Granddaughter delighted!
# 4             Great start to my acrylic paint hobby.                Five Stars
#    level_0    index  overall        asin  \
# 0        0  1817478        5  B01EVJ8Q0Q
# 1        1  1817479        2  B01EVJ8Q0Q
# 2        2  1817480        2  B01EVJ8Q0Q
# 3        3  1817481        5  B01EVJ8Q0Q
# 4        4  1817482        5  B01EVJ8Q0Q
#
#                                           reviewText  \
# 0  The quality of these colors is very good!  The...
# 1  The first tube of paint I tried to use was fil...
# 2  I bought this paint set for the vivid colors. ...
# 3  This review is for Acrylic paint 24 Set by Cra...
# 4  Great set of paints! It's realy nice that the ...
#
#                                             summary
# 0                           Good Colors & Brushes!!
# 1    The first tube of paint I tried to use was ...
# 2                                              Dull
# 3  Nice Set of 24 Appealing Colors at a Great Price
# 4                           Great set for beginners
#    level_0    index  overall        asin  \
# 0        0  1819698        5  B01EVNLJ4M
# 1        1  1819699        5  B01EVNLJ4M
# 2        2  1819700        2  B01EVNLJ4M
# 3        3  1819701        3  B01EVNLJ4M
# 4        4  1819702        5  B01EVNLJ4M
#
#                                           reviewText  \
# 0  fast service great colors high quality colored...
# 1  Huge selection of color. They colors are bold,...
# 2  I purchased these at full price based on so ma...
# 3  These pencils are okay.  They are probably one...
# 4                       My daughter loves the colors
#
#                      summary
# 0                 Five Stars
# 1             Great Product.
# 2  You get what you pay for.
# 3              Okay for Kids
# 4                   Worth it
#    level_0    index  overall        asin  \
# 0        0  1824256        5  B01F2VZQWI
# 1        1  1824257        5  B01F2VZQWI
# 2        2  1824258        5  B01F2VZQWI
# 3        3  1824259        3  B01F2VZQWI
# 4        4  1824260        5  B01F2VZQWI
#
#                                           reviewText                   summary
# 0  This is a great product. I love that it is cle...           Awesome product
# 1  This transfer tape is the best I've used and I...           Great product!!
# 2  Great Product! Fast Shipping! Favorite Transfe...             Great Product
# 3  Just what I needed.  Not the first time I used...  Craftopia is my favorite
# 4  great product! applies to my vinyl very easily...           so easy to use!
#    level_0    index  overall        asin  \
# 0        0  1846849        5  B01G4GRUBU
# 1        1  1846850        5  B01G4GRUBU
# 2        2  1846851        5  B01G4GRUBU
# 3        3  1846852        4  B01G4GRUBU
# 4        4  1846853        3  B01G4GRUBU
#
#                                           reviewText  \
# 0  Love this drawing paper got this for a review ...
# 1  We go through a ton of these with a young arti...
# 2                                      Nice product.
# 3                           Very good for sketching.
# 4  Paper is more on the rough side. I prefer a sm...
#
#                                              summary
# 0                                        Great paper
# 1   Great sketchbook for the price, beautiful covers
# 2  Perfect art pad for drawing with my granddaughter
# 3                 Paper weight light for watercolor.
# 4                       Okay, but not my cup of tea.
#    level_0    index  overall        asin  \
# 0        0  1853206        5  B01GGUAIX6
# 1        1  1853207        5  B01GGUAIX6
# 2        2  1853208        5  B01GGUAIX6
# 3        3  1853209        5  B01GGUAIX6
# 4        4  1853210        5  B01GGUAIX6
#
#                                           reviewText  \
# 0                              Perfect for my needs.
# 1  <div id="video-block-R2KBPYVA87IXZ8" class="a-...
# 2  If you are always looking through drawers tryi...
# 3  These scissors are sharp but the handles are n...
# 4  These scissors are as advertised. Sharp and pe...
#
#                                              summary
# 0                                         Five Stars
# 1                                 Sharper Than Sharp
# 2         Best Titanium Scissors - 5 Pack - 8" Blade
# 3                                                 ok
# 4  Great multi-purpose scissors and is as sharp a...
#    level_0    index  overall        asin  \
# 0        0  1855824        5  B01GLS0C2K
# 1        1  1855825        5  B01GLS0C2K
# 2        2  1855826        4  B01GLS0C2K
# 3        3  1855827        5  B01GLS0C2K
# 4        4  1855828        4  B01GLS0C2K
#
#                                           reviewText  \
# 0         No complaints. Love the variety of colors!
# 1  These are the best gel pens I've used and I've...
# 2                      Great product and great price
# 3  Great quality and quick shipping. I would defi...
# 4  I was going to send them back when I first rec...
#
#                                              summary
# 0                         Love the variety of colors
# 1                       The best gel pens I've used!
# 2                                 Happy with my pens
# 3  Great product - tons of colors - writing quali...
# 4                                       NICE PEN SET
#    level_0    index  overall        asin  \
# 0        0  1867586        5  B01H5FYNX2
# 1        1  1867587        5  B01H5FYNX2
# 2        2  1867588        4  B01H5FYNX2
# 3        3  1867589        5  B01H5FYNX2
# 4        4  1867590        5  B01H5FYNX2
#
#                                           reviewText  \
# 0  I was afraid these would either dry up too qui...
# 1                           Great price good product
# 2  These pens are great! Write smoothly and evenl...
# 3  The color quality is fantastic and I like the ...
# 4  Love them! It's so hard to find colored pens s...
#
#                             summary
# 0  Great for Notebooks and Journals
# 1                        Five Stars
# 2                        Four Stars
# 3                        Five Stars
# 4                        Five Stars

# %%
print(len(ans))
# Out:
# 150

# %%
# !mkdir /Review
# !mkdir /Overall
# !mkdir /Summary

# %%
for i in range (len(ans)):
  single_ans =  ans[i]
  tempans = ans[i].to_csv(columns=['reviewText'], header=None, index=None)
  #print(tempans)
  filename = "/Review/" + single_ans['asin'][0] + ".txt"
  f1 = open(filename,"a+")
  f1.write(tempans)

# %%
for i in range (len(ans)):
  single_ans1 =  ans[i]
  tempans1 = ans[i].to_csv(columns=['overall'], header=None, index=None)
  #print(tempans)
  filename1 = "/Overall/" + single_ans1['asin'][0] + ".txt"
  f1 = open(filename1,"a+")
  f1.write(tempans1)

# %%
for i in range (len(ans)):
  single_ans2 =  ans[i]
  tempans2 = ans[i].to_csv(columns=['summary'], header=None, index=None)
  #print(tempans)
  filename2 = "/Summary/" + single_ans2['asin'][0] + ".txt"
  f1 = open(filename2,"a+")
  f1.write(tempans2)

# %%
# !zip -r /Review.zip /Review
# !zip -r /Overall.zip /Overall
# !zip -r /Summary.zip /Summary

# %%
from google.colab import files
files.download("/Review.zip")
files.download("/Overall.zip")
files.download("/Summary.zip")

# %% [markdown]
# #END
